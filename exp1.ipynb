# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
image=cv2.imread('/content/6ab37dcdfd8150b6dfbb512b3b40e64b.jpg')
kernel2=np.ones((3,3),np.float16)/9
img=cv2.filter2D(src=image,ddepth=0,kernel=kernel2)
cv2_imshow(image)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x539>
# <PIL.Image.Image image mode=RGB size=640x539>
